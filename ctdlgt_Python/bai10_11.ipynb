# %%
#CÂY THỨ TỰ TRƯỚC
import random


# A demonstration of traversing a binary search tree in order.
# See the traverse function for all the action.


# Generic binary tree class

class Tree:

    def __init__(self, value):
        self._left = None
        self._right = None
        self._value = value

    def setLeftChild(self, child):
        self._left = child

    def setRightChild(self, child):
        self._right = child

    def getLeftChild(self):
        return self._left

    def getRightChild(self):
        return self._right

    def getValue(self):
        return self._value


# Traverse a binary search tree -- if we're expecting very deep
# trees, an iterative rather than recursive method would be safer;
# or consider Stackless Python, although it's not truly stackless
# (http://www.stackless.com/pipermail/stackless/2012-October/005461.html)

# "yield" allows us to use the function in a generator (see below)

def traverse(bst):
    left = bst.getLeftChild()
    if left is not None:
        for subtree in traverse(left):
            yield subtree
    yield bst.getValue()
    right = bst.getRightChild()
    if right is not None:
        for subtree in traverse(right):
            yield subtree


# Helper method for adding a new value

def add(bst, value):
    # Lower values to the left
    if value < bst.getValue():
        left = bst.getLeftChild()
        if left is None:
            bst.setLeftChild(Tree(value))
        else:
            add(left, value)
    # Higher values to the right
    elif value > bst.getValue():
        right = bst.getRightChild()
        if right is None:
            bst.setRightChild(Tree(value))
        else:
            add(right, value)
    # If value == bst.getValue(), take no action (it's a duplicate)


# Generate some test data

bst = Tree(50)
for i in range(100):
    value = random.randint(0, 100)
    print ("Adding value ", value)
    add(bst, value)

print( "In order: ", list(x for x in traverse(bst)))
# Out:
# Adding value  14
# Adding value  88
# Adding value  12
# Adding value  42
# Adding value  26
# Adding value  84
# Adding value  6
# Adding value  8
# Adding value  99
# Adding value  15
# Adding value  69
# Adding value  6
# Adding value  92
# Adding value  63
# Adding value  0
# Adding value  34
# Adding value  22
# Adding value  58
# Adding value  56
# Adding value  19
# Adding value  56
# Adding value  20
# Adding value  49
# Adding value  58
# Adding value  95
# Adding value  15
# Adding value  13
# Adding value  50
# Adding value  85
# Adding value  52
# Adding value  9
# Adding value  98
# Adding value  56
# Adding value  83
# Adding value  66
# Adding value  99
# Adding value  82
# Adding value  70
# Adding value  55
# Adding value  6
# Adding value  83
# Adding value  5
# Adding value  96
# Adding value  43
# Adding value  72
# Adding value  78
# Adding value  6
# Adding value  24
# Adding value  83
# Adding value  83
# Adding value  28
# Adding value  1
# Adding value  41
# Adding value  23
# Adding value  76
# Adding value  73
# Adding value  55
# Adding value  35
# Adding value  97
# Adding value  89
# Adding value  34
# Adding value  32
# Adding value  53
# Adding value  84
# Adding value  20
# Adding value  40
# Adding value  73
# Adding value  83
# Adding value  99
# Adding value  0
# Adding value  22
# Adding value  77
# Adding value  47
# Adding value  17
# Adding value  49
# Adding value  58
# Adding value  33
# Adding value  33
# Adding value  7
# Adding value  35
# Adding value  32
# Adding value  65
# Adding value  81
# Adding value  83
# Adding value  50
# Adding value  21
# Adding value  79
# Adding value  27
# Adding value  33
# Adding value  43
# Adding value  54
# Adding value  93
# Adding value  13
# Adding value  88
# Adding value  68
# Adding value  45
# Adding value  94
# Adding value  98
# Adding value  63
# Adding value  13
# In order:  [0, 1, 5, 6, 7, 8, 9, 12, 13, 14, 15, 17, 19, 20, 21, 22, 23, 24, 26, 27, 28, 32, 33, 34, 35, 40, 41, 42, 43, 45, 47, 49, 50, 52, 53, 54, 55, 56, 58, 63, 65, 66, 68, 69, 70, 72, 73, 76, 77, 78, 79, 81, 82, 83, 84, 85, 88, 89, 92, 93, 94, 95, 96, 97, 98, 99]

# %%
#CÂY THỨ TỰ SAU
